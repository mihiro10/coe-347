# %%
import pandas as pd
import numpy as np #importing numpy
cars = pd.read_csv('../project_data/project1_data.csv')

# %%
cars_numeric_cols = cars.select_dtypes(include=[np.number])
cars_one_hot_encoded = pd.get_dummies(cars_numeric_cols, columns=['origin'], prefix='origin')

# %%
cars_cleaned = cars_one_hot_encoded

# %%
cars_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   weight        398 non-null    int64
#  4   acceleration  398 non-null    float64
#  5   model_year    398 non-null    int64
#  6   origin_1      398 non-null    bool
#  7   origin_2      398 non-null    bool
#  8   origin_3      398 non-null    bool
# dtypes: bool(3), float64(3), int64(3)
# memory usage: 19.9 KB

# %%
cars_cleaned
# Out:
#       mpg  cylinders  displacement  weight  acceleration  model_year  \
# 0    18.0          8         307.0    3504          12.0          70
# 1    15.0          8         350.0    3693          11.5          70
# 2    18.0          8         318.0    3436          11.0          70
# 3    16.0          8         304.0    3433          12.0          70
# 4    17.0          8         302.0    3449          10.5          70
# ..    ...        ...           ...     ...           ...         ...
# 393  27.0          4         140.0    2790          15.6          82
# 394  44.0          4          97.0    2130          24.6          82
# 395  32.0          4         135.0    2295          11.6          82
# 396  28.0          4         120.0    2625          18.6          82
# 397  31.0          4         119.0    2720          19.4          82
#
#      origin_1  origin_2  origin_3
# 0        True     False     False
# 1        True     False     False
# ...

# %%
import sklearn
from sklearn import linear_model
lr = linear_model.LinearRegression()

# Split into training and testing 

# Define the split point
split_point = 200

# Split the DataFrame into training and testing sets
training_data = cars_cleaned.iloc[:split_point]
testing_data = cars_cleaned.iloc[split_point:]

# %%
training_data
# Out:
#       mpg  cylinders  displacement  weight  acceleration  model_year  \
# 0    18.0          8         307.0    3504          12.0          70
# 1    15.0          8         350.0    3693          11.5          70
# 2    18.0          8         318.0    3436          11.0          70
# 3    16.0          8         304.0    3433          12.0          70
# 4    17.0          8         302.0    3449          10.5          70
# ..    ...        ...           ...     ...           ...         ...
# 195  29.0          4          85.0    2035          22.2          76
# 196  24.5          4          98.0    2164          22.1          76
# 197  29.0          4          90.0    1937          14.2          76
# 198  33.0          4          91.0    1795          17.4          76
# 199  20.0          6         225.0    3651          17.7          76
#
#      origin_1  origin_2  origin_3
# 0        True     False     False
# 1        True     False     False
# ...

# %%
testing_data
# Out:
#       mpg  cylinders  displacement  weight  acceleration  model_year  \
# 200  18.0          6         250.0    3574          21.0          76
# 201  18.5          6         250.0    3645          16.2          76
# 202  17.5          6         258.0    3193          17.8          76
# 203  29.5          4          97.0    1825          12.2          76
# 204  32.0          4          85.0    1990          17.0          76
# ..    ...        ...           ...     ...           ...         ...
# 393  27.0          4         140.0    2790          15.6          82
# 394  44.0          4          97.0    2130          24.6          82
# 395  32.0          4         135.0    2295          11.6          82
# 396  28.0          4         120.0    2625          18.6          82
# 397  31.0          4         119.0    2720          19.4          82
#
#      origin_1  origin_2  origin_3
# 200      True     False     False
# 201      True     False     False
# ...

# %%
# Assuming cars_cleaned is a DataFrame with the columns 'weight' and 'mpg'
training_dataset_weight = [[weight] for weight in training_data['weight']]
training_dataset_mpg = [[mpg] for mpg in training_data['mpg']]
testing_dataset_weight = [[weight] for weight in testing_data['weight']]
testing_dataset_mpg = [[mpg] for mpg in testing_data['mpg']]

# %%
training_dataset_weight
# Out:
# [[3504],
#  [3693],
#  [3436],
#  [3433],
#  [3449],
#  [4341],
#  [4354],
#  [4312],
#  [4425],
#  [3850],
#  [3563],
#  [3609],
#  [3761],
#  [3086],
#  [2372],
#  [2833],
#  [2774],
#  [2587],
#  [2130],
#  [1835],
#  [2672],
#  [2430],
#  [2375],
#  [2234],
#  [2648],
#  [4615],
#  [4376],
#  [4382],
#  [4732],
#  [2130],
#  [2264],
#  [2228],
#  [2046],
#  [2634],
#  [3439],
#  [3329],
#  [3302],
#  [3288],
#  [4209],
#  [4464],
#  [4154],
#  [4096],
#  [4955],
#  [4746],
#  [5140],
#  [2962],
#  [2408],
#  [3282],
#  [3139],
#  [2220],
#  [2123],
#  [2074],
#  [2065],
#  [1773],
#  [1613],
#  [1834],
#  [1955],
#  [2278],
#  [2126],
#  [2254],
#  [2408],
#  [2226],
#  [4274],
#  [4385],
#  [4135],
#  [4129],
#  [3672],
#  [4633],
#  [4502],
#  [4456],
#  [4422],
#  [2330],
#  [3892],
#  [4098],
#  [4294],
#  [4077],
#  [2933],
#  [2511],
#  [2979],
#  [2189],
#  [2395],
#  [2288],
#  [2506],
#  [2164],
#  [2100],
#  [4100],
#  [3672],
#  [3988],
#  [4042],
#  [3777],
# ...

# %%
training_dataset_mpg
# Out:
# [[18.0],
#  [15.0],
#  [18.0],
#  [16.0],
#  [17.0],
#  [15.0],
#  [14.0],
#  [14.0],
#  [14.0],
#  [15.0],
#  [15.0],
#  [14.0],
#  [15.0],
#  [14.0],
#  [24.0],
#  [22.0],
#  [18.0],
#  [21.0],
#  [27.0],
#  [26.0],
#  [25.0],
#  [24.0],
#  [25.0],
#  [26.0],
#  [21.0],
#  [10.0],
#  [10.0],
#  [11.0],
#  [9.0],
#  [27.0],
#  [28.0],
#  [25.0],
#  [25.0],
#  [19.0],
#  [16.0],
#  [17.0],
#  [19.0],
#  [18.0],
#  [14.0],
#  [14.0],
#  [14.0],
#  [14.0],
#  [12.0],
#  [13.0],
#  [13.0],
#  [18.0],
#  [22.0],
#  [19.0],
#  [18.0],
#  [23.0],
#  [28.0],
#  [30.0],
#  [30.0],
#  [31.0],
#  [35.0],
#  [27.0],
#  [26.0],
#  [24.0],
#  [25.0],
#  [23.0],
#  [20.0],
#  [21.0],
#  [13.0],
#  [14.0],
#  [15.0],
#  [14.0],
#  [17.0],
#  [11.0],
#  [13.0],
#  [12.0],
#  [13.0],
#  [19.0],
#  [15.0],
#  [13.0],
#  [13.0],
#  [14.0],
#  [18.0],
#  [22.0],
#  [21.0],
#  [26.0],
#  [22.0],
#  [28.0],
#  [23.0],
#  [28.0],
#  [27.0],
#  [13.0],
#  [14.0],
#  [13.0],
#  [14.0],
#  [15.0],
#  [12.0],
# ...

# %%
lr.fit(training_dataset_weight, training_dataset_mpg)
# Out:
# LinearRegression()

# %%
test_predict_weight = lr.predict(test_dataset_weight) # values predicted by model on the test data

# %%
# plot the data with the trat
>>> import matplotlib.pyplot as plt

>>> plt.scatter(test_dataset_weight, test_dataset_mpg, color="black")
>>> plt.plot(test_dataset_weight, test_predict_weight, color="blue", linewidth=3)
